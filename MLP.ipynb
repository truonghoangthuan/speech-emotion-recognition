# %% [markdown]
# #Speech Emotion Recognition with MLP Classifier

# %% [markdown]
# #Dataset
# The Ryerson Audio-Visual Database of Emotional Speech and Song (RAVDESS)
#
# ---
# Audio-only files
#
# Audio-only files of all actors (01-24) are available as two separate zip files (~200 MB each):
#
# Speech file (Audio_Speech_Actors_01-24.zip, 215 MB) contains 1440 files: 60 trials per actor x 24 actors = 1440.
# Song file (Audio_Song_Actors_01-24.zip, 198 MB) contains 1012 files: 44 trials per actor x 23 actors = 1012.
#
# Total=2452
#
# ---
#
# ---
# Toronto emotional speech set (TESS)
#
# ---
#
#
# There are a set of 200 target words were spoken in the carrier phrase "Say the word _' by two actresses (aged 26 and 64 years) and recordings were made of the set portraying each of seven emotions (anger, disgust, fear, happiness, pleasant surprise, sadness, and neutral). There are 2800 data points (audio files) in total.
#
# The dataset is organised such that each of the two female actor and their emotions are contain within its own folder. And within that, all 200 target words audio file can be found. The format of the audio file is a WAV format
#
#
# ---

# %% [markdown]
# # Mount google drive

# %%
from google.colab import drive
drive.mount('/content/drive/')

# %% [markdown]
# # Install following libraries

# %%
# %pip install --upgrade pip
# %pip install setuptools wheel
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in /Users/truonghoangthuan/Library/Python/3.9/lib/python/site-packages (22.3)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: setuptools in /Users/truonghoangthuan/Library/Python/3.9/lib/python/site-packages (65.5.0)
# Requirement already satisfied: wheel in /Users/truonghoangthuan/Library/Python/3.9/lib/python/site-packages (0.37.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install librosa soundfile numpy sklearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: librosa in /Users/truonghoangthuan/Library/Python/3.9/lib/python/site-packages (0.9.2)
# Requirement already satisfied: soundfile in /Users/truonghoangthuan/Library/Python/3.9/lib/python/site-packages (0.11.0)
# Requirement already satisfied: numpy in /Users/truonghoangthuan/Library/Python/3.9/lib/python/site-packages (1.23.4)
# Requirement already satisfied: sklearn in /Users/truonghoangthuan/Library/Python/3.9/lib/python/site-packages (0.0)
# Requirement already satisfied: audioread>=2.1.9 in /Users/truonghoangthuan/Library/Python/3.9/lib/python/site-packages (from librosa) (3.0.0)
# Requirement already satisfied: scipy>=1.2.0 in /Users/truonghoangthuan/Library/Python/3.9/lib/python/site-packages (from librosa) (1.9.3)
# Requirement already satisfied: scikit-learn>=0.19.1 in /Users/truonghoangthuan/Library/Python/3.9/lib/python/site-packages (from librosa) (1.1.2)
# Requirement already satisfied: numba>=0.45.1 in /Users/truonghoangthuan/Library/Python/3.9/lib/python/site-packages (from librosa) (0.56.3)
# Requirement already satisfied: decorator>=4.0.10 in /Users/truonghoangthuan/Library/Python/3.9/lib/python/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: packaging>=20.0 in /Users/truonghoangthuan/Library/Python/3.9/lib/python/site-packages (from librosa) (21.3)
# Requirement already satisfied: pooch>=1.0 in /Users/truonghoangthuan/Library/Python/3.9/lib/python/site-packages (from librosa) (1.6.0)
# Requirement already satisfied: resampy>=0.2.2 in /Users/truonghoangthuan/Library/Python/3.9/lib/python/site-packages (from librosa) (0.4.2)
# Requirement already satisfied: joblib>=0.14 in /Users/truonghoangthuan/Library/Python/3.9/lib/python/site-packages (from librosa) (1.2.0)
# Requirement already satisfied: cffi>=1.0 in /Users/truonghoangthuan/Library/Python/3.9/lib/python/site-packages (from soundfile) (1.15.1)
# Requirement already satisfied: pycparser in /Users/truonghoangthuan/Library/Python/3.9/lib/python/site-packages (from cffi>=1.0->soundfile) (2.21)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /Users/truonghoangthuan/Library/Python/3.9/lib/python/site-packages (from numba>=0.45.1->librosa) (0.39.1)
# Requirement already satisfied: setuptools in /Users/truonghoangthuan/Library/Python/3.9/lib/python/site-packages (from numba>=0.45.1->librosa) (65.5.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/truonghoangthuan/Library/Python/3.9/lib/python/site-packages (from packaging>=20.0->librosa) (3.0.9)
# Requirement already satisfied: requests>=2.19.0 in /Users/truonghoangthuan/Library/Python/3.9/lib/python/site-packages (from pooch>=1.0->librosa) (2.28.1)
# Requirement already satisfied: appdirs>=1.3.0 in /Users/truonghoangthuan/Library/Python/3.9/lib/python/site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/truonghoangthuan/Library/Python/3.9/lib/python/site-packages (from scikit-learn>=0.19.1->librosa) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/truonghoangthuan/Library/Python/3.9/lib/python/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/truonghoangthuan/Library/Python/3.9/lib/python/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/truonghoangthuan/Library/Python/3.9/lib/python/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/truonghoangthuan/Library/Python/3.9/lib/python/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2022.9.24)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install soundfile
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: soundfile in /Users/truonghoangthuan/Library/Python/3.9/lib/python/site-packages (0.11.0)
# Requirement already satisfied: cffi>=1.0 in /Users/truonghoangthuan/Library/Python/3.9/lib/python/site-packages (from soundfile) (1.15.1)
# Requirement already satisfied: pycparser in /Users/truonghoangthuan/Library/Python/3.9/lib/python/site-packages (from cffi>=1.0->soundfile) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Make the necessary imports

# %%
import librosa
import soundfile
import os, glob, pickle
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# Define a function extract_feature to extract the mfcc, chroma, and mel features from a sound file. This function takes 4 parameters- the file name and three Boolean parameters for the three features:
#
# * mfcc: Mel Frequency Cepstral Coefficient, represents the short-term power spectrum of a sound
# * chroma: Pertains to the 12 different pitch classes
# * mel: Mel Spectrogram Frequency

# %%
def extract_feature(file_name, mfcc, chroma, mel):
    X, sample_rate = librosa.load(os.path.join(file_name), res_type='kaiser_fast')
    if chroma:
        stft=np.abs(librosa.stft(X))
    result=np.array([])
    if mfcc:
        mfccs=np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T, axis=0)
        result=np.hstack((result, mfccs))
    if chroma:
        chroma=np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)
        result=np.hstack((result, chroma))
    if mel:
        mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
        result=np.hstack((result, mel))
    return result

# %% [markdown]
# Now, let’s define a dictionary to hold numbers and the emotions available in the RAVDESS & TESS dataset, and a list to hold all 8 emotions- neutral,calm,happy,sad,angry,fearful,disgust,surprised.

# %%
# Emotions in the RAVDESS & TESS dataset
emotions={
  '01':'neutral',
  '02':'calm',
  '03':'happy',
  '04':'sad',
  '05':'angry',
  '06':'fearful',
  '07':'disgust',
  '08':'surprised'
}
# Emotions to observe
observed_emotions=['neutral','calm','happy','sad','angry','fearful', 'disgust','surprised']

# %% [markdown]
# # Load the data and extract features for each sound file

# %%
def load_data(test_size=0.2):
    x,y=[],[]
    for file in glob.glob('./dataset_features/Actor_*/*.wav'):
        file_name=os.path.basename(file)
        emotion=emotions[file_name.split("-")[2]]
        if emotion not in observed_emotions:
            continue
        feature=extract_feature(file, mfcc=True, chroma=True, mel=True)
        x.append(feature)
        y.append(emotion)
    return train_test_split(np.array(x), y, test_size=test_size, train_size= 0.75,random_state=9)

# %% [markdown]
# # Split the Dataset
# Time to split the dataset into training and testing sets! Let’s keep the test set 25% of everything and use the load_data function for this.

# %%
# Split the dataset
import time
x_train,x_test,y_train,y_test=load_data(test_size=0.25)
# Out:
# /var/folders/_q/pj12y4f55hvfz_jdmq_4q8k40000gn/T/ipykernel_1499/4288720281.py:13: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...
-04  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/_q/pj12y4f55hvfz_jdmq_4q8k40000gn/T/ipykernel_1499/4288720281.py:13: FutureWarning: Pass y=[-1.4782323e-04 -2.4475271e-04 -2.2458956e-04 ... -6.1219034e-05
#  -7.8277713e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/_q/pj12y4f55hvfz_jdmq_4q8k40000gn/T/ipykernel_1499/4288720281.py:13: FutureWarning: Pass y=[2.8797642e-05 6.8615038e-05 4.6010238e-05 ... 2.3549482e-04 2.7810299e-04
#  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/_q/pj12y4f55hvfz_jdmq_4q8k40000gn/T/ipykernel_1499/4288720281.py:13: FutureWarning: Pass y=[-4.2522264e-05 -6.8140893e-05 -4.6340610e-05 ...  0.0000000e+00
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/_q/pj12y4f55hvfz_jdmq_4q8k40000gn/T/ipykernel_1499/4288720281.py:13: FutureWarning: Pass y=[-6.4621192e-05 -9.9313707e-05 -8.7886510e-05 ... -7.0665760e-07
#   1.1416989e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/_q/pj12y4f55hvfz_jdmq_4q8k40000gn/T/ipykernel_1499/4288720281.py:13: FutureWarning: Pass y=[-1.3688541e-06 -4.4255644e-06 -2.4090212e-05 ...  2.9905108e-05
#   5.7139045e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/_q/pj12y4f55hvfz_jdmq_4q8k40000gn/T/ipykernel_1499/4288720281.py:13: FutureWarning: Pass y=[ 7.0574295e-08 -8.6708255e-08  8.5680007e-08 ... -5.4067891e-06
#   2.5285744e-06  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/_q/pj12y4f55hvfz_jdmq_4q8k40000gn/T/ipykernel_1499/4288720281.py:13: FutureWarning: Pass y=[-1.3589003e-04 -2.1569488e-04 -1.9275180e-04 ...  3.6104509e-05
#   3.5441892e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/_q/pj12y4f55hvfz_jdmq_4q8k40000gn/T/ipykernel_1499/4288720281.py:13: FutureWarning: Pass y=[-3.3051692e-05 -5.3603988e-05 -5.4544173e-05 ...  8.6961372e-05
#   9.4030009e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/_q/pj12y4f55hvfz_jdmq_4q8k40000gn/T/ipykernel_1499/4288720281.py:13: FutureWarning: Pass y=[0.00013104 0.00021058 0.00018752 ... 0.         0.         0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)

# %% [markdown]
# #Observe the shape of the training and testing datasets:

# %%
#Get the shape of the training and testing datasets
print((x_train.shape[0], x_test.shape[0]))
# Out:
# (3939, 1313)

# %% [markdown]
# # Number of features extracted.

# %%
# Get the number of features extracted
print(f'Features extracted: {x_train.shape[1]}')
# Out:
# Features extracted: 180

# %% [markdown]
# # MLP Classifier

# %%
# Initialize the Multi Layer Perceptron Classifier
model=MLPClassifier(alpha=0.01, batch_size=256, epsilon=1e-08, hidden_layer_sizes=(300,), learning_rate='adaptive', max_iter=500)

# %% [markdown]
# #Fit/train the model.

# %%
# Train the model
model.fit(x_train,y_train)
# Out:
# MLPClassifier(alpha=0.01, batch_size=256, hidden_layer_sizes=(300,),
#               learning_rate='adaptive', max_iter=500)

# %% [markdown]
# # Predict the accuracy of our model

# %% [markdown]
# Let’s predict the values for the test set. This gives us y_pred (the predicted emotions for the features in the test set).

# %%
# Predict for the test set
y_pred=model.predict(x_test)

# %% [markdown]
# To calculate the accuracy of our model, we’ll call up the accuracy_score() function we imported from sklearn. Finally, we’ll round the accuracy to 2 decimal places and print it out.

# %%
# Calculate the accuracy of our model
accuracy=accuracy_score(y_true=y_test, y_pred=y_pred)
# Print the accuracy
print("Accuracy: {:.2f}%".format(accuracy*100))
# Out:
# Accuracy: 79.97%

# %% [markdown]
# #classification Report

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.97      0.79      0.87       188
#         calm       0.80      0.48      0.60        82
#      disgust       0.80      0.83      0.81       162
#      fearful       0.79      0.84      0.81       203
#        happy       0.89      0.75      0.81       192
#      neutral       0.64      0.95      0.76       152
#          sad       0.77      0.82      0.79       187
#    surprised       0.85      0.80      0.82       147
#
#     accuracy                           0.80      1313
#    macro avg       0.81      0.78      0.78      1313
# weighted avg       0.82      0.80      0.80      1313

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
matrix = confusion_matrix(y_test,y_pred)
print (matrix)
# Out:
# [[148   0   8  15   4   4   5   4]
#  [  0  39   2   2   3  29   7   0]
#  [  0   0 134   1   0  12   8   7]
#  [  3   0   4 170   5   8  13   0]
#  [  2   8   5   9 144  14   4   6]
#  [  0   1   0   0   0 145   5   1]
#  [  0   1   6  15   1   8 153   3]
#  [  0   0   9   4   5   8   4 117]]

# %% [markdown]
# #Thank You
